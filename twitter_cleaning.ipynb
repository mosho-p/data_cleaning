# %% [markdown]
# source: https://github.com/GateNLP/broad_twitter_corpus

# %%
import pandas as pd
import numpy as np
import json
import os
import re
from IPython.display import display
pd.options.display.max_columns = None

# %%
with open('data/a.no-labels.json') as f:
    print('Example tweet:', f.readline())
    print('Number of tweets:', str(sum([1 for x in f.readlines()]) + 1))
# Out:
# Example tweet: {"contributors": null, "truncated": false, "text": "I lobe Hobo Rob #JS", "is_quote_status": false, "in_reply_to_status_id": null, "id": 153928603371978755, "favorite_count": 0, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [], "hashtags": [{"indices": [16, 19], "text": "JS"}], "urls": []}, "in_reply_to_screen_name": null, "in_reply_to_user_id": null, "retweet_count": 0, "id_str": "153928603371978755", "favorited": false, "user": {"follow_request_sent": false, "has_extended_profile": false, "profile_use_background_image": true, "default_profile_image": false, "id": 288360633, "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg", "verified": false, "profile_text_color": "080008", "profile_image_url_https": "https://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg", "profile_sidebar_fill_color": "DDEEF6", "entities": {"url": {"urls": [{"url": "https://t.co/jBfkD1QXM4", "indices": [0, 23], "expanded_url": "https://twitter.com/reasereaser/status/319928467741343744", "display_url": "twitter.com/reasereaser/st\u2026"}]}, "description": {"urls": []}}, "followers_count": 2398, "profile_sidebar_border_color": "FFFFFF", "id_str": "288360633", "profile_background_color": "C0DEED", "listed_count": 12, "is_translation_enabled": false, "utc_offset": 3600, "statuses_count": 26726, "description": "Kristen , Lana , Mary , Jennifer , David LESBIAN and PROUD", "friends_count": 2491, "location": "Forks/District12/Storybrooke ", "profile_link_color": "102472", "profile_image_url": "http://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg", "following": false, "geo_enabled": true, "profile_banner_url": "https://pbs.twimg.com/profile_banners/288360633/1429700158", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg", "screen_name": "ParrillaIsPerf", "lang": "en", "profile_background_tile": true, "favourites_count": 106, "name": "Parrilla\u2764\ufe0fStewart", "notifications": false, "url": "https://t.co/jBfkD1QXM4", "created_at": "Tue Apr 26 18:25:49 +0000 2011", "contributors_enabled": false, "time_zone": "London", "protected": false, "default_profile": false, "is_translator": false}, "geo": null, "in_reply_to_user_id_str": null, "lang": "en", "created_at": "Mon Jan 02 20:00:13 +0000 2012", "in_reply_to_status_id_str": null, "place": null}
#
# Number of tweets: 774

# %% [markdown]
# #### Perfect, nice and messy. Also small enough to hold in memory.

# %%
with open('data/a.no-labels.json') as f:
    a_tweets = [json.loads(tweet) for tweet in f.readlines()]

# %%
df_a = pd.read_json('data/a.no-labels.json', lines=True)

# %%
# I might be doing this a lot as I work through the data:
def summary(dataframe):
    display(dataframe.head())
    display(dataframe.tail())
    display(dataframe.info())

# %%
summary(df_a)
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2012-01-02 20:00:13
# 1           NaN        None 2012-01-01 22:46:07
# 2           NaN        None 2012-01-02 19:21:59
# 3           NaN        None 2012-01-01 13:56:06
# 4           NaN        None 2012-01-04 14:39:29
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 1  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 2  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 3  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 4  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  153928603371978755  153928603371978752
# 1               0      False  None  153607964278788096  153607964278788096
# 2               0      False  None  153918980111859713  153918980111859712
# 3               1      False  None  153474582488162304  153474582488162304
# 4               0      False  None  154572662419632128  154572662419632128
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  \
# 0                  NaN                      NaN            False   en  None
# 1                  NaN                      NaN            False   en  None
# 2                  NaN                      NaN            False   pt  None
# 3                  NaN                      NaN            False   en  None
# 4                  NaN                      NaN            False   en  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              0      False
# 1                 NaN              0      False
# 2                 NaN              0      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://blackberry.com/twitter" rel="n...
# 3  <a href="http://blackberry.com/twitter" rel="n...
# 4  <a href="http://www.echofon.com/" rel="nofollo...
#
#                                                 text  truncated  \
# 0                                I lobe Hobo Rob #JS      False
# 1  Deciding whether or not to add my parents in f...      False
# 2                                FUUUUUULHAAAAAAM!!!      False
# 3  Think you call that smash and grab. #Gateshead...      False
# 4  Rachid Harkouk #randomformerfootballers #qpr #...      False
#
#                                                 user
# 0  {'follow_request_sent': False, 'has_extended_p...
# 1  {'follow_request_sent': False, 'has_extended_p...
# 2  {'follow_request_sent': False, 'has_extended_p...
# 3  {'follow_request_sent': False, 'has_extended_p...
# 4  {'follow_request_sent': False, 'has_extended_p...
#      contributors coordinates          created_at  \
# 769           NaN        None 2012-01-30 15:41:01
# 770           NaN        None 2012-01-29 15:33:08
# 771           NaN        None 2012-01-29 18:30:33
# 772           NaN        None 2012-01-31 09:13:58
# 773           NaN        None 2012-01-30 11:36:18
#
#                                               entities extended_entities  \
# 769  {'symbols': [], 'user_mentions': [{'id': 98618...               NaN
# 770  {'symbols': [], 'user_mentions': [{'id': 15715...               NaN
# 771  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 772  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 773  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#      favorite_count  favorited   geo                  id              id_str  \
# 769               0      False  None  164010231964254208  164010231964254208
# 770               0      False  None  163645862424215552  163645862424215552
# 771               0      False  None  163690508777029633  163690508777029632
# 772               0      False  None  164275217018011648  164275217018011648
# 773               0      False  None  163948647745200129  163948647745200128
#
#     in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 769                    None                    NaN                        NaN
# 770                    None                    NaN                        NaN
# 771                    None                    NaN                        NaN
# 772                    None                    NaN                        NaN
# 773                    None                    NaN                        NaN
#
#      in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  \
# 769                  NaN                      NaN            False   en  None
# 770                  NaN                      NaN            False   en  None
# 771                  NaN                      NaN            False   en  None
# 772                  NaN                      NaN            False   en  None
# 773                  NaN                      NaN            False   en  None
#
#      possibly_sensitive  retweet_count  retweeted  \
# 769                 NaN              1      False
# 770                 0.0              0      False
# 771                 NaN              0      False
# 772                 NaN              0      False
# 773                 NaN              1      False
#
#                                                 source  \
# 769  <a href="http://twitter.com" rel="nofollow">Tw...
# 770  <a href="http://tvtag.com" rel="nofollow">tvta...
# 771  <a href="http://twitter.com" rel="nofollow">Tw...
# 772  <a href="http://twitter.com" rel="nofollow">Tw...
# 773  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  truncated  \
# 769  Just invited to attend #twittersalon 'a new re...      False
# 770  Love me some Alexander Payne. Love me some Geo...      False
# 771  Completley love life!! But would appreciate it...      False
# 772  Note to self: water in my windscreen washers w...      False
# 773  Delon Armitage has been suspended from the Eng...      False
#
#                                                   user
# 769  {'follow_request_sent': False, 'has_extended_p...
# 770  {'follow_request_sent': False, 'has_extended_p...
# 771  {'follow_request_sent': False, 'has_extended_p...
# 772  {'follow_request_sent': False, 'has_extended_p...
# 773  {'follow_request_sent': False, 'has_extended_p...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 25 columns):
# contributors                 0 non-null float64
# coordinates                  23 non-null object
# created_at                   774 non-null datetime64[ns]
# entities                     774 non-null object
# extended_entities            13 non-null object
# favorite_count               774 non-null int64
# favorited                    774 non-null bool
# geo                          23 non-null object
# id                           774 non-null int64
# id_str                       774 non-null int64
# in_reply_to_screen_name      1 non-null object
# in_reply_to_status_id        1 non-null float64
# in_reply_to_status_id_str    1 non-null float64
# in_reply_to_user_id          1 non-null float64
# in_reply_to_user_id_str      1 non-null float64
# is_quote_status              774 non-null bool
# lang                         774 non-null object
# place                        29 non-null object
# possibly_sensitive           236 non-null float64
# retweet_count                774 non-null int64
# retweeted                    774 non-null bool
# source                       774 non-null object
# text                         774 non-null object
# truncated                    774 non-null bool
# user                         774 non-null object
# dtypes: bool(4), datetime64[ns](1), float64(6), int64(4), object(10)
# memory usage: 130.1+ KB
# None

# %% [markdown]
# #### What I see:
# * I can definitely drop `contributors`.
# * I'm curious about `in_reply_to...`
# * `coordinates, extended_entities, geo, places` will most likely not be useable
# * `possibly_sensitive` might be True/False with one of the options being represented by `NaN`
# * `entities` and `user` contain dicts that need digging into
# * `text` will have additional information such as hashtags that need separating

# %% [markdown]
# #### Before I go any further, some of the other files might have useful info in these columns, or other columns that this file doesn't have

# %% [markdown]
# #### I have 6 json files, I need to see if the keys are different:

# %%
def preview_data(file_name):
    """Print metadata about the file, then return the list of columns for comparison with other files"""
    with open('data/'+file_name) as f:
        print(file_name)
        print('Number of tweets:', str(sum([1 for x in f.readlines()])))
        f.seek(0)
        return set(json.loads(f.readline()).keys())

# %%
json_files = sorted([x for x in os.listdir('data/') if re.match(r'.\.no-labels\.json', x)])
print(*json_files, sep='\n')   # all of the twitter json files
# Out:
# a.no-labels.json
# b.no-labels.json
# e.no-labels.json
# f.no-labels.json
# g.no-labels.json
# h.no-labels.json

# %%
keys = set(df_a.columns)
for file in json_files:
    x = preview_data(file)
    if x-keys:  # column in one file and not in others
        print(x-keys)
    keys.update(x)
    print()
# Out:
# a.no-labels.json
# Number of tweets: 774
#
# b.no-labels.json
# Number of tweets: 1521
#
# e.no-labels.json
# Number of tweets: 200
# {'langid_conf', 'langid'}
#
# f.no-labels.json
# Number of tweets: 2000
#
# g.no-labels.json
# Number of tweets: 2138
#
# h.no-labels.json
# Number of tweets: 2000
# {'filter_level'}

# %% [markdown]
# #### I can work with all of this data in memory. There are some files with extra keys.

# %%
df_book = dict()
for file in json_files:
    df_book[file[0]+'_df'] = pd.read_json('data/'+file, lines=True)

# %%
full_df = pd.concat(df_book.values(), axis=0, ignore_index=True, sort=False)

# %%
summary(full_df)
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2012-01-02 20:00:13
# 1           NaN        None 2012-01-01 22:46:07
# 2           NaN        None 2012-01-02 19:21:59
# 3           NaN        None 2012-01-01 13:56:06
# 4           NaN        None 2012-01-04 14:39:29
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 1  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 2  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 3  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 4  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  153928603371978755  153928603371978752
# 1               0      False  None  153607964278788096  153607964278788096
# 2               0      False  None  153918980111859713  153918980111859712
# 3               1      False  None  153474582488162304  153474582488162304
# 4               0      False  None  154572662419632128  154572662419632128
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str is_quote_status lang place  \
# 0                  NaN                      NaN           False   en  None
# 1                  NaN                      NaN           False   en  None
# 2                  NaN                      NaN           False   pt  None
# 3                  NaN                      NaN           False   en  None
# 4                  NaN                      NaN           False   en  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              0      False
# 1                 NaN              0      False
# 2                 NaN              0      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://blackberry.com/twitter" rel="n...
# 3  <a href="http://blackberry.com/twitter" rel="n...
# 4  <a href="http://www.echofon.com/" rel="nofollo...
#
#                                                 text  truncated  \
# 0                                I lobe Hobo Rob #JS      False
# 1  Deciding whether or not to add my parents in f...      False
# 2                                FUUUUUULHAAAAAAM!!!      False
# 3  Think you call that smash and grab. #Gateshead...      False
# 4  Rachid Harkouk #randomformerfootballers #qpr #...      False
#
#                                                 user langid  langid_conf  \
# 0  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 1  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 2  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 3  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 4  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
#
#   scopes filter_level retweeted_status
# 0    NaN          NaN              NaN
# 1    NaN          NaN              NaN
# 2    NaN          NaN              NaN
# 3    NaN          NaN              NaN
# 4    NaN          NaN              NaN
#       contributors coordinates          created_at  \
# 8628           NaN        None 2014-04-23 14:57:09
# 8629           NaN        None 2014-03-01 17:45:59
# 8630           NaN        None 2014-07-17 13:56:50
# 8631           NaN        None 2014-05-07 10:30:53
# 8632           NaN        None 2014-05-07 10:31:19
#
#                                                entities extended_entities  \
# 8628  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 8629  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 8630  {'user_mentions': [], 'symbols': [], 'trends':...               NaN
# 8631  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 8632  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#       favorite_count  favorited   geo                  id              id_str  \
# 8628               0      False  None  458982917616586753  458982917616586752
# 8629               0      False  None  439818849215848448  439818849215848448
# 8630               0      False  None  489770706821861378  489770706821861376
# 8631               0      False  None  463989339475951616  463989339475951616
# 8632               0      False  None  463989448552640512  463989448552640512
#
#      in_reply_to_screen_name  in_reply_to_status_id  \
# 8628               fyBTSVee_           4.589819e+17
# 8629                    None                    NaN
# 8630                    None                    NaN
# 8631                    None                    NaN
# 8632                    None                    NaN
#
#       in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  \
# 8628               4.589819e+17         1.383929e+09             1.383929e+09
# 8629                        NaN                  NaN                      NaN
# 8630                        NaN                  NaN                      NaN
# 8631                        NaN                  NaN                      NaN
# 8632                        NaN                  NaN                      NaN
#
#      is_quote_status lang place  possibly_sensitive  retweet_count  retweeted  \
# 8628             NaN   en  None                 NaN              0      False
# 8629             NaN   de  None                 0.0              0      False
# 8630             NaN   en  None                 0.0              0      False
# 8631             NaN   en  None                 0.0              0      False
# 8632             NaN   en  None                 NaN              0      False
#
#                                                  source  \
# 8628  <a href="http://twitter.com/download/android" ...
# 8629  <a href="http://twitter.com/download/iphone" r...
# 8630  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 8631  <a href="http://twitter.com/#!/download/ipad" ...
# 8632  <a href="http://sandaysoft.com/" rel="nofollow...
#
#                                                    text  truncated  \
# 8628  @fyBTSVee_ okay :) anyway, if i change, do you...      False
# 8629  RT @MOVIEMEMORlES: #OneOfMyFavoriteMoviesIs Th...      False
# 8630  Provide you 165+ real and permanent linkedin s...      False
# 8631  Kermit &amp; Steve Martin, la nuova rainbow co...      False
# 8632  Wind 0 km/h S. Barometer 1023.3 hPa, Rising sl...      False
#
#                                                    user langid  langid_conf  \
# 8628  {'follow_request_sent': None, 'profile_use_bac...     en     1.000000
# 8629  {'follow_request_sent': None, 'profile_use_bac...     en     0.999996
# 8630  {'follow_request_sent': None, 'profile_use_bac...     en     1.000000
# 8631  {'follow_request_sent': None, 'profile_use_bac...     en     0.999010
# 8632  {'follow_request_sent': None, 'profile_use_bac...     en     0.999887
#
#      scopes filter_level                                   retweeted_status
# 8628    NaN       medium                                                NaN
# 8629    NaN       medium  {'contributors': None, 'truncated': False, 'te...
# 8630    NaN       medium                                                NaN
# 8631    NaN       medium                                                NaN
# 8632    NaN       medium                                                NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 30 columns):
# contributors                 0 non-null float64
# coordinates                  149 non-null object
# created_at                   8633 non-null datetime64[ns]
# entities                     8633 non-null object
# extended_entities            713 non-null object
# favorite_count               8633 non-null int64
# favorited                    8633 non-null bool
# geo                          149 non-null object
# id                           8633 non-null int64
# id_str                       8633 non-null int64
# in_reply_to_screen_name      1233 non-null object
# in_reply_to_status_id        1089 non-null float64
# in_reply_to_status_id_str    1089 non-null float64
# in_reply_to_user_id          1233 non-null float64
# in_reply_to_user_id_str      1233 non-null float64
# is_quote_status              2295 non-null object
# lang                         8633 non-null object
# place                        184 non-null object
# possibly_sensitive           4569 non-null float64
# retweet_count                8633 non-null int64
# retweeted                    8633 non-null bool
# source                       8633 non-null object
# text                         8633 non-null object
# truncated                    8633 non-null bool
# user                         8633 non-null object
# langid                       2200 non-null object
# langid_conf                  2200 non-null float64
# scopes                       1 non-null object
# filter_level                 2000 non-null object
# retweeted_status             487 non-null object
# dtypes: bool(3), datetime64[ns](1), float64(7), int64(4), object(15)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# #### Now I can drop contributors with confidence

# %%
def func_on_all_dfs(func, keys=['a_df', 'b_df', 'e_df', 'f_df', 'g_df', 'h_df']):
    """
    Perform transformation functions in place on all of the separate dataframes.
    param keys (list): specify dataframes to change. For example, if some dataframes are missing a column.
    """
    global full_df, df_book
    full_df = func(full_df)
    for k in keys:
        df_book[k] = func(df_book[k])

# %%
func_on_all_dfs(lambda x: x.drop(columns='contributors'))

# %%
summary(full_df)
# Out:
#   coordinates          created_at  \
# 0        None 2012-01-02 20:00:13
# 1        None 2012-01-01 22:46:07
# 2        None 2012-01-02 19:21:59
# 3        None 2012-01-01 13:56:06
# 4        None 2012-01-04 14:39:29
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 1  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 2  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 3  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 4  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  153928603371978755  153928603371978752
# 1               0      False  None  153607964278788096  153607964278788096
# 2               0      False  None  153918980111859713  153918980111859712
# 3               1      False  None  153474582488162304  153474582488162304
# 4               0      False  None  154572662419632128  154572662419632128
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str is_quote_status lang place  \
# 0                  NaN                      NaN           False   en  None
# 1                  NaN                      NaN           False   en  None
# 2                  NaN                      NaN           False   pt  None
# 3                  NaN                      NaN           False   en  None
# 4                  NaN                      NaN           False   en  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              0      False
# 1                 NaN              0      False
# 2                 NaN              0      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://blackberry.com/twitter" rel="n...
# 3  <a href="http://blackberry.com/twitter" rel="n...
# 4  <a href="http://www.echofon.com/" rel="nofollo...
#
#                                                 text  truncated  \
# 0                                I lobe Hobo Rob #JS      False
# 1  Deciding whether or not to add my parents in f...      False
# 2                                FUUUUUULHAAAAAAM!!!      False
# 3  Think you call that smash and grab. #Gateshead...      False
# 4  Rachid Harkouk #randomformerfootballers #qpr #...      False
#
#                                                 user langid  langid_conf  \
# 0  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 1  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 2  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 3  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 4  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
#
#   scopes filter_level retweeted_status
# 0    NaN          NaN              NaN
# 1    NaN          NaN              NaN
# 2    NaN          NaN              NaN
# 3    NaN          NaN              NaN
# 4    NaN          NaN              NaN
#      coordinates          created_at  \
# 8628        None 2014-04-23 14:57:09
# 8629        None 2014-03-01 17:45:59
# 8630        None 2014-07-17 13:56:50
# 8631        None 2014-05-07 10:30:53
# 8632        None 2014-05-07 10:31:19
#
#                                                entities extended_entities  \
# 8628  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 8629  {'symbols': [], 'user_mentions': [{'indices': ...               NaN
# 8630  {'user_mentions': [], 'symbols': [], 'trends':...               NaN
# 8631  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 8632  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#       favorite_count  favorited   geo                  id              id_str  \
# 8628               0      False  None  458982917616586753  458982917616586752
# 8629               0      False  None  439818849215848448  439818849215848448
# 8630               0      False  None  489770706821861378  489770706821861376
# 8631               0      False  None  463989339475951616  463989339475951616
# 8632               0      False  None  463989448552640512  463989448552640512
#
#      in_reply_to_screen_name  in_reply_to_status_id  \
# 8628               fyBTSVee_           4.589819e+17
# 8629                    None                    NaN
# 8630                    None                    NaN
# 8631                    None                    NaN
# 8632                    None                    NaN
#
#       in_reply_to_status_id_str  in_reply_to_user_id  in_reply_to_user_id_str  \
# 8628               4.589819e+17         1.383929e+09             1.383929e+09
# 8629                        NaN                  NaN                      NaN
# 8630                        NaN                  NaN                      NaN
# 8631                        NaN                  NaN                      NaN
# 8632                        NaN                  NaN                      NaN
#
#      is_quote_status lang place  possibly_sensitive  retweet_count  retweeted  \
# 8628             NaN   en  None                 NaN              0      False
# 8629             NaN   de  None                 0.0              0      False
# 8630             NaN   en  None                 0.0              0      False
# 8631             NaN   en  None                 0.0              0      False
# 8632             NaN   en  None                 NaN              0      False
#
#                                                  source  \
# 8628  <a href="http://twitter.com/download/android" ...
# 8629  <a href="http://twitter.com/download/iphone" r...
# 8630  <a href="http://dlvr.it" rel="nofollow">dlvr.i...
# 8631  <a href="http://twitter.com/#!/download/ipad" ...
# 8632  <a href="http://sandaysoft.com/" rel="nofollow...
#
#                                                    text  truncated  \
# 8628  @fyBTSVee_ okay :) anyway, if i change, do you...      False
# 8629  RT @MOVIEMEMORlES: #OneOfMyFavoriteMoviesIs Th...      False
# 8630  Provide you 165+ real and permanent linkedin s...      False
# 8631  Kermit &amp; Steve Martin, la nuova rainbow co...      False
# 8632  Wind 0 km/h S. Barometer 1023.3 hPa, Rising sl...      False
#
#                                                    user langid  langid_conf  \
# 8628  {'follow_request_sent': None, 'profile_use_bac...     en     1.000000
# 8629  {'follow_request_sent': None, 'profile_use_bac...     en     0.999996
# 8630  {'follow_request_sent': None, 'profile_use_bac...     en     1.000000
# 8631  {'follow_request_sent': None, 'profile_use_bac...     en     0.999010
# 8632  {'follow_request_sent': None, 'profile_use_bac...     en     0.999887
#
#      scopes filter_level                                   retweeted_status
# 8628    NaN       medium                                                NaN
# 8629    NaN       medium  {'contributors': None, 'truncated': False, 'te...
# 8630    NaN       medium                                                NaN
# 8631    NaN       medium                                                NaN
# 8632    NaN       medium                                                NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 29 columns):
# coordinates                  149 non-null object
# created_at                   8633 non-null datetime64[ns]
# entities                     8633 non-null object
# extended_entities            713 non-null object
# favorite_count               8633 non-null int64
# favorited                    8633 non-null bool
# geo                          149 non-null object
# id                           8633 non-null int64
# id_str                       8633 non-null int64
# in_reply_to_screen_name      1233 non-null object
# in_reply_to_status_id        1089 non-null float64
# in_reply_to_status_id_str    1089 non-null float64
# in_reply_to_user_id          1233 non-null float64
# in_reply_to_user_id_str      1233 non-null float64
# is_quote_status              2295 non-null object
# lang                         8633 non-null object
# place                        184 non-null object
# possibly_sensitive           4569 non-null float64
# retweet_count                8633 non-null int64
# retweeted                    8633 non-null bool
# source                       8633 non-null object
# text                         8633 non-null object
# truncated                    8633 non-null bool
# user                         8633 non-null object
# langid                       2200 non-null object
# langid_conf                  2200 non-null float64
# scopes                       1 non-null object
# filter_level                 2000 non-null object
# retweeted_status             487 non-null object
# dtypes: bool(3), datetime64[ns](1), float64(6), int64(4), object(15)
# memory usage: 1.7+ MB
# None

# %%
full_df['possibly_sensitive'].value_counts(dropna=False)
# Out:
#  0.0    4506
# NaN     4064
#  1.0      63
# Name: possibly_sensitive, dtype: int64

# %% [markdown]
# #### Now I'm wondering if some files used 0/1 and others used 0/NaN

# %%
for k, v in df_book.items():
    print(k)
    print(v.possibly_sensitive.value_counts(dropna=False))
    print()
# Out:
# a_df
# NaN     538
#  0.0    235
#  1.0      1
# Name: possibly_sensitive, dtype: int64
#
# b_df
# NaN     1100
#  0.0     419
#  1.0       2
# Name: possibly_sensitive, dtype: int64
#
# e_df
#  0.0    121
# NaN      75
#  1.0      4
# Name: possibly_sensitive, dtype: int64
#
# f_df
# NaN     1102
#  0.0     867
#  1.0      31
# Name: possibly_sensitive, dtype: int64
#
# g_df
#  0.0    1654
# NaN      484
# Name: possibly_sensitive, dtype: int64
#
# h_df
#  0.0    1210
# NaN      765
#  1.0      25
# Name: possibly_sensitive, dtype: int64

# %% [markdown]
# #### NaN really does mean 'not specified', so I can't fill in these values yet

# %%
full_df.filter_level.unique()
# Out:
# array([nan, 'medium', 'none'], dtype=object)

# %% [markdown]
# #### user, retweeted_status, and entities contain dicts. Let's see what's in them

# %%
full_df[~full_df.user.isna()].iloc[0]['user']
# Out:
# {'follow_request_sent': False,
#  'has_extended_profile': False,
#  'profile_use_background_image': True,
#  'default_profile_image': False,
#  'id': 288360633,
#  'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg',
#  'verified': False,
#  'profile_text_color': '080008',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/jBfkD1QXM4',
#      'indices': [0, 23],
#      'expanded_url': 'https://twitter.com/reasereaser/status/319928467741343744',
#      'display_url': 'twitter.com/reasereaser/st…'}]},
#   'description': {'urls': []}},
#  'followers_count': 2398,
#  'profile_sidebar_border_color': 'FFFFFF',
#  'id_str': '288360633',
#  'profile_background_color': 'C0DEED',
#  'listed_count': 12,
#  'is_translation_enabled': False,
#  'utc_offset': 3600,
#  'statuses_count': 26726,
#  'description': 'Kristen , Lana , Mary , Jennifer , David LESBIAN and PROUD',
#  'friends_count': 2491,
#  'location': 'Forks/District12/Storybrooke ',
#  'profile_link_color': '102472',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg',
#  'following': False,
#  'geo_enabled': True,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/288360633/1429700158',
#  'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg',
#  'screen_name': 'ParrillaIsPerf',
#  'lang': 'en',
#  'profile_background_tile': True,
#  'favourites_count': 106,
#  'name': 'Parrilla❤️Stewart',
#  'notifications': False,
#  'url': 'https://t.co/jBfkD1QXM4',
#  'created_at': 'Tue Apr 26 18:25:49 +0000 2011',
#  'contributors_enabled': False,
#  'time_zone': 'London',
#  'protected': False,
#  'default_profile': False,
#  'is_translator': False}

# %%
full_df[~full_df.entities.isna()].reset_index().iloc[0]['entities']
# Out:
# {'symbols': [],
#  'user_mentions': [],
#  'hashtags': [{'indices': [16, 19], 'text': 'JS'}],
#  'urls': []}

# %%
full_df[~full_df.retweeted_status.isna()].iloc[0]['retweeted_status']
# Out:
# {'contributors': None,
#  'truncated': False,
#  'text': "I'm like really over a lot of shit .",
#  'in_reply_to_status_id': None,
#  'id': 458883332109893632,
#  'favorite_count': 1,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'retweeted': False,
#  'coordinates': None,
#  'entities': {'symbols': [], 'user_mentions': [], 'hashtags': [], 'urls': []},
#  'in_reply_to_screen_name': None,
#  'id_str': '458883332109893632',
#  'retweet_count': 4,
#  'in_reply_to_user_id': None,
#  'favorited': False,
#  'user': {'follow_request_sent': None,
#   'profile_use_background_image': True,
#   'id': 352848740,
#   'verified': False,
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/458889072828616706/1FkfM3uD_normal.jpeg',
#   'profile_sidebar_fill_color': 'EADEAA',
#   'is_translator': False,
#   'geo_enabled': True,
#   'profile_text_color': '333333',
#   'followers_count': 934,
#   'protected': False,
#   'location': '',
#   'default_profile_image': False,
#   'id_str': '352848740',
#   'lang': 'en',
#   'utc_offset': None,
#   'statuses_count': 18068,
#   'description': None,
#   'friends_count': 696,
#   'profile_link_color': '9D582E',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/458889072828616706/1FkfM3uD_normal.jpeg',
#   'notifications': None,
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#   'profile_background_color': '8B542B',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#   'screen_name': 'briahndorothy',
#   'is_translation_enabled': False,
#   'profile_background_tile': False,
#   'favourites_count': 4569,
#   'name': 'Bri •',
#   'url': None,
#   'created_at': 'Thu Aug 11 04:45:47 +0000 2011',
#   'contributors_enabled': False,
#   'time_zone': None,
#   'profile_sidebar_border_color': 'D9B17E',
#   'default_profile': False,
#   'following': None,
#   'listed_count': 1},
#  'geo': None,
#  'in_reply_to_user_id_str': None,
#  'lang': 'en',
#  'created_at': 'Wed Apr 23 08:21:26 +0000 2014',
#  'in_reply_to_status_id_str': None,
#  'place': None}

# %% [markdown]
# #### There are many commonalities between user and the information collected in the other columns

# %%
set(full_df.columns).difference(full_df[~full_df.user.isna()].iloc[0]['user'].keys())
# Out:
# {'coordinates',
#  'extended_entities',
#  'favorite_count',
#  'favorited',
#  'filter_level',
#  'geo',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'langid',
#  'langid_conf',
#  'place',
#  'possibly_sensitive',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'scopes',
#  'source',
#  'text',
#  'truncated',
#  'user'}

# %%
set(full_df.columns)&(full_df[~full_df.user.isna()].iloc[0]['user'].keys())
# Out:
# {'created_at', 'entities', 'id', 'id_str', 'lang'}

# %% [markdown]
# ### Creating a Hashtags column

# %%
"#hey".split('#')
# Out:
# ['', 'hey']

# %%
a="hey #hey #what and now text but then #butts"
a="notags"

# %%
a.split('#')[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-cc821d74e62e> in <module>
# ----> 1 a.split('#')[1]
#
# IndexError: list index out of range

# %%
[[x.split()[0] for x in b.split('#') if x] for b in a]
# Out:
# [['hey', 'what', 'butts'], ['test']]

# %%
full_df['hashtags'] = [[tags.split()[0] for tags in (tweet.split('#')+[''])[1:] if tags.strip()] if tweet.find('#')>=0  else None for tweet in full_df['text']]

# %%
full_df.head()
# Out:
#   coordinates          created_at  \
# 0        None 2012-01-02 20:00:13
# 1        None 2012-01-01 22:46:07
# 2        None 2012-01-02 19:21:59
# 3        None 2012-01-01 13:56:06
# 4        None 2012-01-04 14:39:29
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 1  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 2  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 3  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 4  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  153928603371978755  153928603371978752
# 1               0      False  None  153607964278788096  153607964278788096
# 2               0      False  None  153918980111859713  153918980111859712
# 3               1      False  None  153474582488162304  153474582488162304
# 4               0      False  None  154572662419632128  154572662419632128
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str is_quote_status lang place  \
# 0                  NaN                      NaN           False   en  None
# 1                  NaN                      NaN           False   en  None
# 2                  NaN                      NaN           False   pt  None
# 3                  NaN                      NaN           False   en  None
# 4                  NaN                      NaN           False   en  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              0      False
# 1                 NaN              0      False
# 2                 NaN              0      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://blackberry.com/twitter" rel="n...
# 3  <a href="http://blackberry.com/twitter" rel="n...
# 4  <a href="http://www.echofon.com/" rel="nofollo...
#
#                                                 text  truncated  \
# 0                                I lobe Hobo Rob #JS      False
# 1  Deciding whether or not to add my parents in f...      False
# 2                                FUUUUUULHAAAAAAM!!!      False
# 3  Think you call that smash and grab. #Gateshead...      False
# 4  Rachid Harkouk #randomformerfootballers #qpr #...      False
#
#                                                 user langid  langid_conf  \
# 0  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 1  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 2  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 3  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
# 4  {'follow_request_sent': False, 'has_extended_p...    NaN          NaN
#
#   scopes filter_level retweeted_status  \
# 0    NaN          NaN              NaN
# 1    NaN          NaN              NaN
# 2    NaN          NaN              NaN
# 3    NaN          NaN              NaN
# 4    NaN          NaN              NaN
#
#                                      hashtags
# 0                                        [JS]
# 1                                        None
# 2                                        None
# 3                               [Gateshead's]
# 4  [randomformerfootballers, qpr, showsmyage]

# %%
hashtag_validation = set()
_=[hashtag_validation.add(text[text.find(tag)-1]) for text, hashtags in zip(full_df[~full_df.hashtags.isna()]['text'], full_df[~full_df.hashtags.isna()]['hashtags']) for tag in hashtags]

# %%
hashtag_validation
# Out:
# {' ',
#  '#',
#  '-',
#  '4',
#  '@',
#  'A',
#  'C',
#  'G',
#  'I',
#  'T',
#  'W',
#  '_',
#  'a',
#  'd',
#  'e',
#  'h',
#  'l',
#  'm',
#  'n',
#  'o',
#  'r',
#  's',
#  't',
#  'y',
#  '✤'}

# %% [markdown]
# #### The only character here should have been `#` so the script needs fixing. There is probably a case I have not considered yet.

# %% [markdown]
# These last two steps have taken too long due to index errors or data-type mistakes. For now, I am going to focus on learning how to effectively use a debugger to make these kinds of issues smoother in the future.
