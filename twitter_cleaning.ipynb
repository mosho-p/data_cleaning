# %% [markdown]
# source: https://github.com/GateNLP/broad_twitter_corpus

# %%
import pandas as pd
import json
from IPython.display import display
pd.options.display.max_columns = None

# %%
with open('data/twitter_example.json') as f:
    print('Example tweet:', f.readline())
    print('Number of tweets:', str(sum([1 for x in f.readlines()]) + 1))
# Out:
# Example tweet: {"contributors": null, "truncated": false, "text": "I lobe Hobo Rob #JS", "is_quote_status": false, "in_reply_to_status_id": null, "id": 153928603371978755, "favorite_count": 0, "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "retweeted": false, "coordinates": null, "entities": {"symbols": [], "user_mentions": [], "hashtags": [{"indices": [16, 19], "text": "JS"}], "urls": []}, "in_reply_to_screen_name": null, "in_reply_to_user_id": null, "retweet_count": 0, "id_str": "153928603371978755", "favorited": false, "user": {"follow_request_sent": false, "has_extended_profile": false, "profile_use_background_image": true, "default_profile_image": false, "id": 288360633, "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg", "verified": false, "profile_text_color": "080008", "profile_image_url_https": "https://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg", "profile_sidebar_fill_color": "DDEEF6", "entities": {"url": {"urls": [{"url": "https://t.co/jBfkD1QXM4", "indices": [0, 23], "expanded_url": "https://twitter.com/reasereaser/status/319928467741343744", "display_url": "twitter.com/reasereaser/st\u2026"}]}, "description": {"urls": []}}, "followers_count": 2398, "profile_sidebar_border_color": "FFFFFF", "id_str": "288360633", "profile_background_color": "C0DEED", "listed_count": 12, "is_translation_enabled": false, "utc_offset": 3600, "statuses_count": 26726, "description": "Kristen , Lana , Mary , Jennifer , David LESBIAN and PROUD", "friends_count": 2491, "location": "Forks/District12/Storybrooke ", "profile_link_color": "102472", "profile_image_url": "http://pbs.twimg.com/profile_images/614024778618392576/vUxPtoH__normal.jpg", "following": false, "geo_enabled": true, "profile_banner_url": "https://pbs.twimg.com/profile_banners/288360633/1429700158", "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/542747437866049536/uMGEZIRN.jpeg", "screen_name": "ParrillaIsPerf", "lang": "en", "profile_background_tile": true, "favourites_count": 106, "name": "Parrilla\u2764\ufe0fStewart", "notifications": false, "url": "https://t.co/jBfkD1QXM4", "created_at": "Tue Apr 26 18:25:49 +0000 2011", "contributors_enabled": false, "time_zone": "London", "protected": false, "default_profile": false, "is_translator": false}, "geo": null, "in_reply_to_user_id_str": null, "lang": "en", "created_at": "Mon Jan 02 20:00:13 +0000 2012", "in_reply_to_status_id_str": null, "place": null}
#
# Number of tweets: 774

# %% [markdown]
# #### Perfect, nice and messy. Also small enough to hold in memory.

# %%
with open('data/twitter_example.json') as f:
    tweets = [json.loads(tweet) for tweet in f.readlines()]

# %%
df = pd.read_json('data/twitter_example.json', lines=True)

# %%
# I might be doing this a lot as I work through the data:
def summary(dataframe):
    display(dataframe.head())
    display(dataframe.tail())
    display(dataframe.info())

# %%
summary(df)
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2012-01-02 20:00:13
# 1           NaN        None 2012-01-01 22:46:07
# 2           NaN        None 2012-01-02 19:21:59
# 3           NaN        None 2012-01-01 13:56:06
# 4           NaN        None 2012-01-04 14:39:29
#
#                                             entities extended_entities  \
# 0  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 1  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 2  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 3  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 4  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  153928603371978755  153928603371978752
# 1               0      False  None  153607964278788096  153607964278788096
# 2               0      False  None  153918980111859713  153918980111859712
# 3               1      False  None  153474582488162304  153474582488162304
# 4               0      False  None  154572662419632128  154572662419632128
#
#   in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 0                    None                    NaN                        NaN
# 1                    None                    NaN                        NaN
# 2                    None                    NaN                        NaN
# 3                    None                    NaN                        NaN
# 4                    None                    NaN                        NaN
#
#    in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  \
# 0                  NaN                      NaN            False   en  None
# 1                  NaN                      NaN            False   en  None
# 2                  NaN                      NaN            False   pt  None
# 3                  NaN                      NaN            False   en  None
# 4                  NaN                      NaN            False   en  None
#
#    possibly_sensitive  retweet_count  retweeted  \
# 0                 NaN              0      False
# 1                 NaN              0      False
# 2                 NaN              0      False
# 3                 NaN              0      False
# 4                 NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://blackberry.com/twitter" rel="n...
# 3  <a href="http://blackberry.com/twitter" rel="n...
# 4  <a href="http://www.echofon.com/" rel="nofollo...
#
#                                                 text  truncated  \
# 0                                I lobe Hobo Rob #JS      False
# 1  Deciding whether or not to add my parents in f...      False
# 2                                FUUUUUULHAAAAAAM!!!      False
# 3  Think you call that smash and grab. #Gateshead...      False
# 4  Rachid Harkouk #randomformerfootballers #qpr #...      False
#
#                                                 user
# 0  {'follow_request_sent': False, 'has_extended_p...
# 1  {'follow_request_sent': False, 'has_extended_p...
# 2  {'follow_request_sent': False, 'has_extended_p...
# 3  {'follow_request_sent': False, 'has_extended_p...
# 4  {'follow_request_sent': False, 'has_extended_p...
#      contributors coordinates          created_at  \
# 769           NaN        None 2012-01-30 15:41:01
# 770           NaN        None 2012-01-29 15:33:08
# 771           NaN        None 2012-01-29 18:30:33
# 772           NaN        None 2012-01-31 09:13:58
# 773           NaN        None 2012-01-30 11:36:18
#
#                                               entities extended_entities  \
# 769  {'symbols': [], 'user_mentions': [{'id': 98618...               NaN
# 770  {'symbols': [], 'user_mentions': [{'id': 15715...               NaN
# 771  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 772  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
# 773  {'symbols': [], 'user_mentions': [], 'hashtags...               NaN
#
#      favorite_count  favorited   geo                  id              id_str  \
# 769               0      False  None  164010231964254208  164010231964254208
# 770               0      False  None  163645862424215552  163645862424215552
# 771               0      False  None  163690508777029633  163690508777029632
# 772               0      False  None  164275217018011648  164275217018011648
# 773               0      False  None  163948647745200129  163948647745200128
#
#     in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 769                    None                    NaN                        NaN
# 770                    None                    NaN                        NaN
# 771                    None                    NaN                        NaN
# 772                    None                    NaN                        NaN
# 773                    None                    NaN                        NaN
#
#      in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  \
# 769                  NaN                      NaN            False   en  None
# 770                  NaN                      NaN            False   en  None
# 771                  NaN                      NaN            False   en  None
# 772                  NaN                      NaN            False   en  None
# 773                  NaN                      NaN            False   en  None
#
#      possibly_sensitive  retweet_count  retweeted  \
# 769                 NaN              1      False
# 770                 0.0              0      False
# 771                 NaN              0      False
# 772                 NaN              0      False
# 773                 NaN              1      False
#
#                                                 source  \
# 769  <a href="http://twitter.com" rel="nofollow">Tw...
# 770  <a href="http://tvtag.com" rel="nofollow">tvta...
# 771  <a href="http://twitter.com" rel="nofollow">Tw...
# 772  <a href="http://twitter.com" rel="nofollow">Tw...
# 773  <a href="https://about.twitter.com/products/tw...
#
#                                                   text  truncated  \
# 769  Just invited to attend #twittersalon 'a new re...      False
# 770  Love me some Alexander Payne. Love me some Geo...      False
# 771  Completley love life!! But would appreciate it...      False
# 772  Note to self: water in my windscreen washers w...      False
# 773  Delon Armitage has been suspended from the Eng...      False
#
#                                                   user
# 769  {'follow_request_sent': False, 'has_extended_p...
# 770  {'follow_request_sent': False, 'has_extended_p...
# 771  {'follow_request_sent': False, 'has_extended_p...
# 772  {'follow_request_sent': False, 'has_extended_p...
# 773  {'follow_request_sent': False, 'has_extended_p...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 25 columns):
# contributors                 0 non-null float64
# coordinates                  23 non-null object
# created_at                   774 non-null datetime64[ns]
# entities                     774 non-null object
# extended_entities            13 non-null object
# favorite_count               774 non-null int64
# favorited                    774 non-null bool
# geo                          23 non-null object
# id                           774 non-null int64
# id_str                       774 non-null int64
# in_reply_to_screen_name      1 non-null object
# in_reply_to_status_id        1 non-null float64
# in_reply_to_status_id_str    1 non-null float64
# in_reply_to_user_id          1 non-null float64
# in_reply_to_user_id_str      1 non-null float64
# is_quote_status              774 non-null bool
# lang                         774 non-null object
# place                        29 non-null object
# possibly_sensitive           236 non-null float64
# retweet_count                774 non-null int64
# retweeted                    774 non-null bool
# source                       774 non-null object
# text                         774 non-null object
# truncated                    774 non-null bool
# user                         774 non-null object
# dtypes: bool(4), datetime64[ns](1), float64(6), int64(4), object(10)
# memory usage: 130.1+ KB
# None

# %% [markdown]
# #### What I see:
# * I can definitely drop `contributors`.
# * I'm curious about `in_reply_to...`
# * `coordinates, extended_entities, geo, places` will most likely not be useable
# * `possibly_sensitive` might be True/False with one of the options being represented by `NaN`
# * `entities` and `user` contain dicts that need digging into
# * `text` will have additional information such as hashtags that need separating

# %%
df[~df['in_reply_to_screen_name'].isna()]
# Out:
#      contributors coordinates          created_at  \
# 577           NaN        None 2012-01-23 10:25:22
#
#                                               entities  \
# 577  {'symbols': [], 'user_mentions': [{'id': 61878...
#
#                                      extended_entities  favorite_count  \
# 577  {'media': [{'expanded_url': 'http://twitter.co...               0
#
#      favorited   geo                  id              id_str  \
# 577      False  None  161394081933705218  161394081933705216
#
#     in_reply_to_screen_name  in_reply_to_status_id  in_reply_to_status_id_str  \
# 577             TEDxCardiff           1.613938e+17               1.613938e+17
#
#      in_reply_to_user_id  in_reply_to_user_id_str  is_quote_status lang place  \
# 577           61878733.0               61878733.0            False   en  None
#
#      possibly_sensitive  retweet_count  retweeted  \
# 577                 0.0              0      False
#
#                                                 source  \
# 577  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                   text  truncated  \
# 577  Can you nudge me the next time you have a @TED...      False
#
#                                                   user
# 577  {'follow_request_sent': False, 'has_extended_p...
